# %% [markdown]
# Pandas can read from files such as .csv, excel(.xls/xlsx), html(.html) and SAS(.sas7bdat) using the pd.read_ function

# %% [markdown]
# **1. Reading data fro a CSV file format**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('columns.csv')
df
# Out:
#         1999      2000      2001      2002    1999.1    2000.1    2001.1  \
# 0   0.654045  0.641969  0.362616  0.929921  0.309586  0.049323  0.294664
# 1   0.476901  0.326290  0.084285  0.543280  0.203367  0.663712  0.513209
# 2   0.748812  0.506360  0.581869  0.539934  0.675905  0.657155  0.995109
# 3   0.932042  0.303014  0.806558  0.616291  0.412607  0.965497  0.533521
# 4   0.616343  0.644765  0.219709  0.373868  0.993482  0.433389  0.311338
# 5   0.136256  0.948281  0.238689  0.439704  0.987425  0.772673  0.059890
# 6   0.692014  0.723839  0.188167  0.025216  0.424288  0.087831  0.587944
# 7   0.875936  0.682802  0.751940  0.281904  0.378738  0.914868  0.799332
# 8   0.473876  0.113442  0.558832  0.506930  0.595523  0.815719  0.536480
# 9   0.207733  0.909233  0.278874  0.796808  0.823914  0.429459  0.268095
# 10  0.240638  0.847354  0.159347  0.912627  0.386118  0.149469  0.791188
# 11  0.867836  0.686298  0.668956  0.874914  0.877478  0.225737  0.928470
# ...

# %%
# writing a DataFrame to a csv file as output using the .to_csv() method

df.to_csv('col1.csv', index = False)

# %% [markdown]
# **2. Reading data from an excel file**

# %% [markdown]
# Pandas can read data from an excel file excluding formulas and can write data into a new excel file.
# Excel files with macros may cause this read_excel() to crash.

# %%
df = pd.read_excel('Data_dump_10_rows.xlsx', sheet_name = 'Sheet1')
df
# Out:
#    0 FirstName   LastName  Gender        Country  Age       Date    Id
# 0  1     Dulce      Abril  Female  United States   32 2017-10-15  1562
# 1  2      Mara  Hashimoto  Female  Great Britain   25 2016-08-16  1582
# 2  3    Philip       Gent    Male        France    36 2015-05-21  2587
# 3  4  Kathleen     Hanner  Female  United States   25 2017-10-15  3549
# 4  5   Nereida    Magwood  Female  United States   58 2016-08-16  2468
# 5  6    Gaston      Brumm    Male  United States   24 2015-05-21  2554
# 6  7      Etta      Hurn   Female  Great Britain   56 2017-10-15  3598
# 7  8   Earlean     Melgar  Female  United States   27 2016-08-16  2456
# 8  9  Vincenza    Weiland  Female  United States   40 2015-05-21  6548

# %%
# writing a DataFrame to a excel file as output using the .to_excel() method

df.to_excel('Excel_samp1.xlsx', sheet_name = 'Sheet1')

# %% [markdown]
# **3. Reading data from a html file**

# %% [markdown]
# Pandas read_html() will read tables of a webpage and return a list of DataFrame objects

# %%
import pandas as pd

url = "https://en.wikipedia.org/wiki/Indian_Premier_League"

# Read all tables from the page
tables = pd.read_html(url)

# Show how many tables were found
print(f"Number of tables found: {len(tables)}")

# Preview the first table
print(tables[0].head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[71], line 6
#       3 url = "https://en.wikipedia.org/wiki/Indian_Premier_League"
#       5 # Read all tables from the page
# ----> 6 tables = pd.read_html(url)
#       8 # Show how many tables were found
#       9 print(f"Number of tables found: {len(tables)}")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...

# %%
import pandas as pd
import requests

# Step 1: URL
url = "https://en.wikipedia.org/wiki/2025%E2%80%9326_Premier_League"

# Step 2: Custom headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36'
}

# Step 3: Fetch the page
response = requests.get(url, headers=headers)

# Check if successful
if response.status_code == 200:
    # Step 4: Parse HTML content into DataFrames
    tables = pd.read_html(response.text)
    
    print(f"Number of tables found: {len(tables)}")
    print(tables[0].head())  # Show first table
else:
    print(f"Failed to fetch page: {response.status_code}")
# Out:
# Number of tables found: 18
#                 0                             1
# 0          Season                       2025–26
# 1           Dates  15 August 2025 – 24 May 2026
# 2  Matches played                            50
# 3    Goals scored          124 (2.48 per match)
# 4  Top goalscorer      Erling Haaland (6 goals)
# C:\Users\USER\AppData\Local\Temp\ipykernel_1892\4072819085.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %%
df = tables[4]
df
# Out:
#     Pos                     Team  Pld  W  D  L  GF  GA  GD  Pts
# 0     1                Liverpool    5  5  0  0  11   5  +6   15
# 1     2                  Arsenal    5  3  1  1  10   2  +8   10
# 2     3        Tottenham Hotspur    5  3  1  1  10   3  +7   10
# 3     4              Bournemouth    5  3  1  1   6   5  +1   10
# 4     5           Crystal Palace    5  2  3  0   6   2  +4    9
# 5     6                  Chelsea    5  2  2  1  10   5  +5    8
# 6     7               Sunderland    5  2  2  1   6   4  +2    8
# 7     8                   Fulham    5  2  2  1   6   5  +1    8
# 8     9          Manchester City    5  2  1  2   9   5  +4    7
# 9    10                  Everton    5  2  1  2   6   5  +1    7
# 10   11        Manchester United    5  2  1  2   6   8  −2    7
# 11   12             Leeds United    5  2  1  2   4   7  −3    7
# 12   13         Newcastle United    5  1  3  1   3   3   0    6
# 13   14   Brighton & Hove Albion    5  1  2  2   6   8  −2    5
# ...

# %%
print(df.columns)
# Out:
# Index(['Pos', 'Team', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts'], dtype='object')

# %%
df.to_csv('epl.csv', index = False)

# %% [markdown]
# **4. Reading data from a SAS file**

# %%
df = pd.read_sas('eventrepository.sas7bdat')

df
# Out:
#       _NAME_    _CLASS_ _KEYNAME_ _STARTDATE_  _ENDDATE_ _DATEINTRVL_  \
# 0     b'LS1'  b'SIMPLE'      b'.'  2013-10-01        NaT         b'.'
# 1  b'POINT1'  b'SIMPLE'      b'.'  2013-10-01        NaT         b'.'
# 2   b'RAMP1'  b'SIMPLE'      b'.'  2013-10-01        NaT         b'.'
# 3     b'TC1'  b'SIMPLE'      b'.'  2013-10-01        NaT         b'.'
# 4  b'POINT2'  b'SIMPLE'      b'.'  2013-10-01        NaT         b'.'
# 5   b'RAMP2'  b'SIMPLE'      b'.'  2013-10-01        NaT         b'.'
# 6  b'POINT4'  b'SIMPLE'      b'.'  2013-10-01 2014-10-01       b'QTR'
# 7  b'POINT7'  b'SIMPLE'      b'.'  2013-09-01        NaT         b'.'
#
#   _STARTDT_ _ENDDT_ _DTINTRVL_  _STARTOBS_  ...  _DUR_BEFORE_  _DUR_AFTER_  \
# 0       NaT     NaT       b'.'         NaN  ...           0.0          NaN
# 1       NaT     NaT       b'.'         NaN  ...           0.0          0.0
# 2       NaT     NaT       b'.'         NaN  ...           0.0          NaN
# ...

# %%
df.to_csv('sas_data.csv', index = False)

# %% [markdown]
# **DATA PROCESSING**

# %% [markdown]
# Data processing is the conversion of data into usable or desirable form.
# It is carried out using a predefined sequence either manually or automatically

# %%
import pandas as pd
import requests

# Step 1: URL
url = "https://en.wikipedia.org/wiki/Indian_Premier_League"

# Step 2: Custom headers to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36'
}

# Step 3: Fetch the page
response = requests.get(url, headers=headers)

# Check if successful
if response.status_code == 200:
    # Step 4: Parse HTML content into DataFrames
    tables = pd.read_html(response.text)
    
    print(f"Number of tables found: {len(tables)}")
    print(tables[0].head())  # Show first table
else:
    print(f"Failed to fetch page: {response.status_code}")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1892\4233109154.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# Number of tables found: 41
#                0                                      1
# 0            NaN                                    NaN
# 1      Countries                                  India
# 2  Administrator  Board of Control for Cricket in India
# 3   Headquarters                          Mumbai, India
# 4         Format                               Twenty20

# %%
df = tables
df1 = df[5]

# %%
df1
# Out:
#                           Team                    City  \
# 0          Chennai Super Kings     Chennai, Tamil Nadu
# 1               Delhi Capitals        New Delhi, Delhi
# 2               Gujarat Titans      Ahmedabad, Gujarat
# 3        Kolkata Knight Riders    Kolkata, West Bengal
# 4         Lucknow Super Giants  Lucknow, Uttar Pradesh
# 5               Mumbai Indians     Mumbai, Maharashtra
# 6                 Punjab Kings  New Chandigarh, Punjab
# 7             Rajasthan Royals       Jaipur, Rajasthan
# 8  Royal Challengers Bengaluru    Bengaluru, Karnataka
# 9          Sunrisers Hyderabad    Hyderabad, Telangana
#
#                          Home ground  Debut          Captain  \
# 0          M. A. Chidambaram Stadium   2008  Ruturaj Gaikwad
# 1               Arun Jaitley Stadium   2008       Axar Patel
# 2              Narendra Modi Stadium   2022     Shubman Gill
# 3                       Eden Gardens   2008   Ajinkya Rahane
# ...
